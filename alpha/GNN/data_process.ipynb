# %%
import os
import sys
from datetime import timedelta
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from TestData import *

# %%
tickers = [
    # Consumer Discretionary - Large-Cap
    "AMZN","TSLA", "HD", "MCD",
    # Consumer Discretionary - Mid-Cap
    #"ROKU", "YUM", "DLTR", "BURL",
    # Consumer Discretionary - Small-Cap
    # "CROX", "PLNT", "AEO", "PLAY"
    ]
date_range = ("2024-09-25", "2024-09-30")
result = testData(tickers, date_range, method='C2')
# Out:
# Loading and preprocessing data...
# Loading data for AMZN...
# Loading data for TSLA...
# Loading data for HD...
# Loading data for MCD...
# c:\Research\haas-mfe-g2-cg\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Research\haas-mfe-g2-cg\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Research\haas-mfe-g2-cg\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
result['TSLA']['Ticker_Edge_Meta_Data']
# Out:
#                                AMZN        HD       MCD
# 2024-09-25 10:15:00-04:00  0.215082  0.006073  0.323367
# 2024-09-25 10:16:00-04:00  0.251818  0.028242  0.333505
# 2024-09-25 10:17:00-04:00  0.289364  0.093443  0.329359
# 2024-09-25 10:18:00-04:00  0.296417  0.140186  0.319616
# 2024-09-25 10:19:00-04:00  0.345970  0.171407  0.310280
# ...                             ...       ...       ...
# 2024-09-30 15:41:00-04:00  0.559506 -0.488333 -0.266815
# 2024-09-30 15:42:00-04:00  0.569381 -0.502002 -0.299020
# 2024-09-30 15:43:00-04:00  0.581861 -0.519147 -0.333098
# 2024-09-30 15:44:00-04:00  0.593610 -0.498749 -0.335960
# 2024-09-30 15:45:00-04:00  0.598067 -0.480422 -0.329759
#
# [1417 rows x 3 columns]

# %%
result['AMZN']['Ticker_Node_Meta_Data']
# Out:
#                            rtype  publisher_id  instrument_id     open  \
# 2024-09-25 10:15:00-04:00   33.0           2.0          853.0  193.460
# 2024-09-25 10:16:00-04:00   33.0           2.0          853.0  193.240
# 2024-09-25 10:17:00-04:00   33.0           2.0          853.0  193.350
# 2024-09-25 10:18:00-04:00   33.0           2.0          853.0  193.360
# 2024-09-25 10:19:00-04:00   33.0           2.0          853.0  193.370
# ...                          ...           ...            ...      ...
# 2024-09-30 15:41:00-04:00   33.0           2.0          853.0  185.970
# 2024-09-30 15:42:00-04:00   33.0           2.0          853.0  185.905
# 2024-09-30 15:43:00-04:00   33.0           2.0          853.0  185.975
# 2024-09-30 15:44:00-04:00   33.0           2.0          853.0  185.995
# 2024-09-30 15:45:00-04:00   33.0           2.0          853.0  186.240
#
#                               high      low   close   volume symbol  \
# ...
